# %% [markdown]
# # Histogram is showing is graph showing the frequency distribution

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Exmple - say ask fro height of 250 people then how we will make histogram.

x = np.random.normal(100,10,250)
plt.hist(x, color='r')
# Out:
# (array([ 2.,  7., 21., 42., 51., 51., 47., 19.,  8.,  2.]),
#  array([ 68.81475815,  74.93310923,  81.05146032,  87.1698114 ,
#          93.28816248,  99.40651356, 105.52486464, 111.64321572,
#         117.7615668 , 123.87991788, 129.99826896]),
#  <BarContainer object of 10 artists>)
