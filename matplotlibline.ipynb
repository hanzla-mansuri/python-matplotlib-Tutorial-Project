# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ypoint = np.array([3, 8, 1, 10])
plt.plot(ypoint, ls = 'dashed', color = 'r',lw = 5)
plt.show()

# %%
# multiple line
xpoints =np.array([1, 2, 3, 4])
ypoints = np.array([5, 6, 7, 8])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# multiple line
xpoints =np.array([3, 8, 1, 10])
ypoints = np.array([6, 2, 7, 11])

plt.plot(xpoints, lw = '2', color = 'r')
plt.plot(ypoints, lw = '4', color ='g')
plt.show()
